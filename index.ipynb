# %% [markdown]
# <a href="https://colab.research.google.com/github/ZicBusiness/Rodrigo/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!Doctype html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0">
    <meta http-equiv="X-UA-Compatible" content="ie=edge">
    <title>Rodrigo</title>
	<link rel="stylesheet" href="style.css">	
</head>
<body>
   <div class="bgcircle"></div>
   <div class="bgcircle2"><h1>Rodrigo</h1></div>
   <div class="bgcircle3"></div>
		   
	   

</body>
</html>
