# %% [markdown]
# <a href="https://colab.research.google.com/github/ZicBusiness/Rodrigo/blob/main/mystyle.css.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
body{
	display:grid;
	place-items:center center ;
	position: fixed;
        top: 50%;
        left: 50%;
        margin-right: -50%;
        transform: translate(-50%, -50%)
	
  }
	
.bgcircle{
	
	
    height: 1900px;
	width: 1900px;
    background: repeating-conic-gradient(aqua 0deg  10deg ,DeepSkyBlue 10deg 20deg) ;
	border-radius: 100%;
	animation: spin 10s infinite linear ;
	position :fixed;	
	z-index: -1;
    
}

.bgcircle2 {
	
	z-index:1;
	height: 400px;
    width: 400px;
    background-image: linear-gradient(to bottom right, deepskyblue, aqua);
    border-radius: 100%;
	color: white;
	text-align:center;
	font-family: ocr;
	font-size:30px;
	display: flex;
    align-items: center;
    justify-content: center;	
}

.bgcircle3 {
	
	z-index:2;
	height: 800px;
    width: 800px;
    background-color: deepskyblue;
    border-radius: 100%;
	font-size:30px;
	display: flex;
    align-items: center;
    justify-content: center;
	position :absolute;
	opacity:30%;
}

@keyframes spin {
  from{transform:rotate(0deg)}
	to{transform:rotate(360deg)}	
}
